# %%
import pandas as pd

# %%
import sys
sys.path.append('..')

DATA_PATH = r'../data/'
RAW_DATA_PATH = DATA_PATH + r'raw/'

# %%
raw_data_values = pd.read_csv(RAW_DATA_PATH + r'/Richters_Predictor_Modeling_Earthquake_Damage_-_Train_Values.csv')
print(raw_data_values.shape)
raw_data_values.head()
# Out:
# (260601, 39)
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %%
raw_data_values.describe()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count  2.606010e+05   260601.000000   260601.000000   260601.000000
# mean   5.256755e+05       13.900353      701.074685     6257.876148
# std    3.045450e+05        8.033617      412.710734     3646.369645
# min    4.000000e+00        0.000000        0.000000        0.000000
# 25%    2.611900e+05        7.000000      350.000000     3073.000000
# 50%    5.257570e+05       12.000000      702.000000     6270.000000
# 75%    7.897620e+05       21.000000     1050.000000     9412.000000
# max    1.052934e+06       30.000000     1427.000000    12567.000000
#
#        count_floors_pre_eq            age  area_percentage  height_percentage  \
# count        260601.000000  260601.000000    260601.000000      260601.000000
# mean              2.129723      26.535029         8.018051           5.434365
# std               0.727665      73.565937         4.392231           1.918418
# ...

# %%
raw_data_labels = pd.read_csv(RAW_DATA_PATH + r'/Richters_Predictor_Modeling_Earthquake_Damage_-_Train_Labels.csv')
print(raw_data_labels.shape)
# Out:
# (260601, 2)

# %%
raw_data_labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
for column in raw_data_values.columns[1:]:
    print(raw_data_values[column].value_counts())
# Out:
# geo_level_1_id
# 6     24381
# 26    22615
# 10    22079
# 17    21813
# 8     19080
# 7     18994
# 20    17216
# 21    14889
# 4     14568
# 27    12532
# 13     9608
# 11     8220
# 3      7540
# 22     6252
# 25     5624
# 16     4332
# 0      4011
# 9      3958
# 12     3194
# 18     3189
# 1      2701
# 5      2690
# 30     2686
# 15     2320
# 14     1714
# 24     1310
# 23     1121
# 2       931
# 29      396
# 19      372
# 28      265
# Name: count, dtype: int64
# geo_level_2_id
# 39      4038
# 158     2520
# 181     2080
# 1387    2040
# 157     1897
#         ...
# 1330       1
# 1043       1
# 637        1
# 989        1
# 627        1
# Name: count, Length: 1414, dtype: int64
# geo_level_3_id
# 633      651
# 9133     647
# 621      530
# 11246    470
# 2005     466
#         ...
# 2366       1
# 7155       1
# 10733      1
# 97         1
# 3085       1
# Name: count, Length: 11595, dtype: int64
# count_floors_pre_eq
# 2    156623
# 3     55617
# 1     40441
# ...
